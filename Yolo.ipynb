# %%
# !pip install ultralytics opencv-python opencv-python-headless
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---- ----------------------------------- 4.2/38.8 MB 27.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 4.7/38.8 MB 15.0 MB/s eta 0:00:03
#    ------- -------------------------------- 7.3/38.8 MB 12.6 MB/s eta 0:00:03
#    --------- ------------------------------ 9.2/38.8 MB 11.4 MB/s eta 0:00:03
#    ------------ --------------------------- 12.6/38.8 MB 13.4 MB/s eta 0:00:02
#    ------------ --------------------------- 12.6/38.8 MB 13.4 MB/s eta 0:00:02
#    ------------ --------------------------- 12.6/38.8 MB 13.4 MB/s eta 0:00:02
#    ------------ --------------------------- 12.6/38.8 MB 13.4 MB/s eta 0:00:02
#    ------------- -------------------------- 12.8/38.8 MB 7.3 MB/s eta 0:00:04
#    ------------- -------------------------- 12.8/38.8 MB 7.3 MB/s eta 0:00:04
#    ------------- -------------------------- 12.8/38.8 MB 7.3 MB/s eta 0:00:04
# ...

# %%
import cv2
from ultralytics import YOLO

# %%
model = YOLO("./kfold_results/fold_4/weights/best.pt")

# %%
# !yolo task=detect mode=predict model=./kfold_results/fold_4/weights/best.pt conf=0.5 source=./InferenceVideo.mp4 save=True
# Out:
# Ultralytics 8.3.50 🚀 Python-3.12.6 torch-2.5.1+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/1 (frame 1/376) c:\Users\owena\OneDrive\Desktop\Erasmus\Computer Vision\Project\CV-Project\InferenceVideo.mp4: 384x640 8 without_masks, 7 with_masks, 101.8ms
# video 1/1 (frame 2/376) c:\Users\owena\OneDrive\Desktop\Erasmus\Computer Vision\Project\CV-Project\InferenceVideo.mp4: 384x640 10 without_masks, 6 with_masks, 53.9ms
# video 1/1 (frame 3/376) c:\Users\owena\OneDrive\Desktop\Erasmus\Computer Vision\Project\CV-Project\InferenceVideo.mp4: 384x640 12 without_masks, 6 with_masks, 69.0ms
# video 1/1 (frame 4/376) c:\Users\owena\OneDrive\Desktop\Erasmus\Computer Vision\Project\CV-Project\InferenceVideo.mp4: 384x640 12 without_masks, 4 with_masks, 57.8ms
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 cv2.destroyAllWindows()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'
